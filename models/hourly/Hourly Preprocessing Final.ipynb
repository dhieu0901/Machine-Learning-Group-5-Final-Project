# %%
import pandas as pd 
import numpy as np 
path = "D:/PythonCode/DSEB65A_MachineLearningProject_Group5/data/hanoi_weather_data_hourly.csv"
df = pd.read_csv(path)

# %% [markdown]
# ## Handling Missing Value

# %%
df = df.drop(columns=['name', 'address', 'resolvedAddress', 'source', 'latitude', 'longitude', 'severerisk','preciptype', 'snow', 'snowdepth', 'solarenergy', 'solarradiation'])

# %%
print(df.columns)
# Out:
# Index(['datetime', 'temp', 'feelslike', 'dew', 'humidity', 'precip',
#        'precipprob', 'windgust', 'windspeed', 'winddir', 'sealevelpressure',
#        'cloudcover', 'visibility', 'uvindex', 'conditions', 'icon'],
#       dtype='object')

# %%
# Loại bỏ các hàng có giá trị null
df = df.dropna()

# Kiểm tra lại kích thước của DataFrame sau khi loại bỏ
print(df.shape)
# Out:
# (87421, 16)

# %% [markdown]
# ## Time Conversion
# - The code converts the datetime column to a proper datetime format using pd.to_datetime, sets it as the DataFrame index with set_index, and resamples the data to a daily frequency using `resample('D')`. The `mean(numeric_only=True)` aggregates numeric columns by calculating their daily averages, simplifying hourly data into daily summaries for further analysis.

# %%
df['datetime'] = pd.to_datetime(df['datetime'])
df.set_index('datetime', inplace=True)  # Đặt cột thời gian làm chỉ số
df_daily = df.resample('D').mean(numeric_only=True)

# %% [markdown]
# ## Feature Engineer

# %% [markdown]
# ### Wind Feature Engineer
# - The wind direction, measured in degrees, is converted into its sine and cosine components using numpy functions. This transformation allows us to represent the wind direction as cyclical features.

# %%
df['winddir_sin'] = np.sin(np.deg2rad(df['winddir']))
df['winddir_cos'] = np.cos(np.deg2rad(df['winddir']))

# %% [markdown]
# - Using the wind speed and the sine/cosine components of the wind direction, calculate the wind vector components for the north-south (`wind_vector_ns`) and east-west (`wind_vector_ew`) directions.

# %%
df['wind_vector_ns'] = df['windspeed'] * df['winddir_cos']
df['wind_vector_ew'] = df['windspeed'] * df['winddir_sin']
df = df.drop(columns=['winddir'])

# %% [markdown]
# ### Time Feature Engineer

# %%
#Thêm cột ngày trong năm
df_daily['day_of_year'] = df_daily.index.dayofyear
#Mã hóa tuần hoàn bằng sin-cos (cyclical encoding)
df_daily['day_sin'] = np.sin(2 * np.pi * df_daily['day_of_year'] / 365)
df_daily['day_cos'] = np.cos(2 * np.pi * df_daily['day_of_year'] / 365)
#Thêm cả tháng, thứ trong tuần nếu cần
df_daily['month'] = df_daily.index.month
df_daily['day_of_week'] = df_daily.index.dayofweek
df_daily['is_weekend'] = df_daily['day_of_week'].isin([5, 6]).astype(int)  # binary

# %% [markdown]
# - Creating Seasonal Feature

# %%
# Feature mùa và mã hóa one-hot (Season Indicators)
def get_season(month):
    if month in [12, 1, 2]: return 'Winter'
    elif month in [3, 4, 5]: return 'Spring'
    elif month in [6, 7, 8]: return 'Summer'
    else: return 'Fall'
df_daily['season'] = df_daily['month'].apply(get_season)
season_dummies = pd.get_dummies(df_daily['season'], prefix='season')
df_daily = pd.concat([df_daily, season_dummies], axis=1)
# Drop the 'season' column
df_daily = df_daily.drop(columns=['season'])

# Convert all dummy features to numeric
df_daily = df_daily.astype({col: int for col in season_dummies.columns})

# %% [markdown]
# ### Seasonal Decomposition

# %%
from statsmodels.tsa.seasonal import STL
# Đảm bảo index là datetime và sorted (tích hợp từ code mới)
if 'datetime' in df_daily.columns:
    df_daily['datetime'] = pd.to_datetime(df_daily['datetime'])
    df_daily.set_index('datetime', inplace=True)
df_daily.sort_index(inplace=True)  # sort

# Chọn target, handle NaN ban đầu
series_to_decompose = df_daily['temp'].dropna()  # Hoặc fill nếu cần: .fillna(method='ffill')

# STL yearly
stl_yearly = STL(series_to_decompose, period=365, seasonal=13, robust=True)
result_yearly = stl_yearly.fit()

# %%
# Thêm features vào dataset
df_daily['temp_trend_yearly'] = result_yearly.trend
df_daily['temp_seasonal_yearly'] = result_yearly.seasonal
df_daily['temp_resid_yearly'] = result_yearly.resid

# %%
if df_daily[['temp_trend_yearly', 'temp_seasonal_yearly', 'temp_resid_yearly']].isna().any().any():
    # Forward/backward fill để giữ tính liên tục time series
    df_daily[['temp_trend_yearly', 'temp_seasonal_yearly', 'temp_resid_yearly']] = \
        df_daily[['temp_trend_yearly', 'temp_seasonal_yearly', 'temp_resid_yearly']].fillna(method='ffill')
    df_daily[['temp_trend_yearly', 'temp_seasonal_yearly', 'temp_resid_yearly']] = \
        df_daily[['temp_trend_yearly', 'temp_seasonal_yearly', 'temp_resid_yearly']].fillna(method='bfill')

print("NaN after handling:", df_daily[['temp_trend_yearly', 'temp_seasonal_yearly', 'temp_resid_yearly']].isna().sum().sum())

# Kiểm tra head
print(df_daily[['temp', 'temp_seasonal_yearly', 'temp_trend_yearly', 'temp_resid_yearly']].head())
# Out:
# NaN after handling: 0
#                  temp  temp_seasonal_yearly  temp_trend_yearly  \
# datetime
# 2015-09-27  29.629167              4.729238          24.431184
# 2015-09-28  30.283333              5.392690          24.433189
# 2015-09-29  30.758333              5.714577          24.435196
# 2015-09-30  29.933333              5.108645          24.437206
# 2015-10-01  29.408696              4.265492          24.439217
#
#             temp_resid_yearly
# datetime
# 2015-09-27           0.468744
# 2015-09-28           0.457455
# 2015-09-29           0.608560
# 2015-09-30           0.387482
# 2015-10-01           0.703986

# %% [markdown]
# ### Handling Categorical Feature
# - Chuyển dữ liệu định tính hourly thành daily bằng cách lấy mode (dữ liệu xuất hiện nhiều nhất trong 24h)

# %%
def get_mode(series:pd.Series):
    modes = series.mode()
    return modes.iloc[0] if not modes.empty else np.nan

categorical_cols = ['conditions', 'icon']  # ví dụ
df_cat = df[categorical_cols].resample('D').agg(lambda x: get_mode(x))
df_cat_encoded = pd.get_dummies(df_cat, prefix=categorical_cols)
# Convert boolean columns to binary (0 and 1)
df_cat_encoded = df_cat_encoded.astype(int)

# Concatenate the binary-encoded categorical data with the daily dataframe
df_daily = pd.concat([df_daily, df_cat_encoded], axis=1)

# %% [markdown]
# ***Split dataframe to avoid leakage***

# %%
# Chia tập dữ liệu df_daily thành 3 phần train, valid, test
train_size = int(len(df_daily) * 0.7)
valid_size = int(len(df_daily) * 0.15)

df_train = df_daily.iloc[:train_size]
df_valid = df_daily.iloc[train_size:train_size + valid_size]
df_test = df_daily.iloc[train_size + valid_size:]

# Kiểm tra kích thước của các tập dữ liệu
print("Train size:", df_train.shape)
print("Validation size:", df_valid.shape)
print("Test size:", df_test.shape)
# Out:
# Train size: (2557, 37)
# Validation size: (548, 37)
# Test size: (549, 37)

# %% [markdown]
# ### Lag Feature

# %%
def create_lag_features(df, lag_cols, lags, diff_periods=[1, 7]):
    """
    Create lag and difference features for specified columns.

    Parameters:
    - df (pd.DataFrame): The input DataFrame.
    - lag_cols (list): List of column names to create lag features for.
    - lags (list): List of lag values to use.
    - diff_periods (list): List of periods for difference features (default: [1, 7]).

    Returns:
    - pd.DataFrame: DataFrame with lag and difference features added.
    """
    for col in lag_cols:
        for lag in lags:
            df[f'{col}_lag_{lag}'] = df[col].shift(lag)
        for period in diff_periods:
            df[f'{col}_diff_{period}'] = df[col].diff(periods=period)
    return df

# Example usage:
lag_cols = ['temp', 'humidity', 'windspeed', 'cloudcover', 'precip']
lags = [1, 2, 3, 4, 5, 7, 14, 30]
df_train = create_lag_features(df_train, lag_cols, lags)
df_valid = create_lag_features(df_valid, lag_cols, lags)
df_test = create_lag_features(df_test, lag_cols, lags)
# Out:
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_diff_{period}'] = df[col].diff(periods=period)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_diff_{period}'] = df[col].diff(periods=period)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_diff_{period}'] = df[col].diff(periods=period)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_diff_{period}'] = df[col].diff(periods=period)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_diff_{period}'] = df[col].diff(periods=period)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_diff_{period}'] = df[col].diff(periods=period)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_diff_{period}'] = df[col].diff(periods=period)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_diff_{period}'] = df[col].diff(periods=period)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_diff_{period}'] = df[col].diff(periods=period)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_diff_{period}'] = df[col].diff(periods=period)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_diff_{period}'] = df[col].diff(periods=period)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_diff_{period}'] = df[col].diff(periods=period)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_diff_{period}'] = df[col].diff(periods=period)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_diff_{period}'] = df[col].diff(periods=period)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_diff_{period}'] = df[col].diff(periods=period)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_diff_{period}'] = df[col].diff(periods=period)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_diff_{period}'] = df[col].diff(periods=period)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_diff_{period}'] = df[col].diff(periods=period)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_diff_{period}'] = df[col].diff(periods=period)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_diff_{period}'] = df[col].diff(periods=period)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_diff_{period}'] = df[col].diff(periods=period)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_diff_{period}'] = df[col].diff(periods=period)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_diff_{period}'] = df[col].diff(periods=period)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_diff_{period}'] = df[col].diff(periods=period)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_diff_{period}'] = df[col].diff(periods=period)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_diff_{period}'] = df[col].diff(periods=period)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_diff_{period}'] = df[col].diff(periods=period)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_diff_{period}'] = df[col].diff(periods=period)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_lag_{lag}'] = df[col].shift(lag)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_diff_{period}'] = df[col].diff(periods=period)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\1330539411.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_diff_{period}'] = df[col].diff(periods=period)

# %% [markdown]
# ### Rolling Window Feature

# %%
def create_rolling_features(df, lag_cols, windows, min_periods=1):
    """
    Create rolling mean, std, min, max, and sum features for specified columns.

    Parameters:
    - df (pd.DataFrame): The input DataFrame.
    - lag_cols (list): List of column names to create rolling features for.
    - windows (list): List of window sizes for rolling calculations.
    - min_periods (int): Minimum number of observations in the window required to have a value.

    Returns:
    - pd.DataFrame: DataFrame with rolling features added.
    """
    for col in lag_cols:
        for window in windows:
            # Rolling on past data (shift(1) to avoid leakage)
            shifted = df[col]
            df[f'{col}_roll_mean_{window}'] = shifted.rolling(window=window, min_periods=min_periods).mean()
            df[f'{col}_roll_std_{window}'] = shifted.rolling(window=window, min_periods=min_periods).std()

            # Add min/max/sum for specific columns
            if col in ['temp', 'precip', 'windspeed']:
                df[f'{col}_roll_min_{window}'] = shifted.rolling(window=window, min_periods=min_periods).min()
                df[f'{col}_roll_max_{window}'] = shifted.rolling(window=window, min_periods=min_periods).max()
            if col == 'precip':
                df[f'{col}_roll_sum_{window}'] = shifted.rolling(window=window, min_periods=min_periods).sum()
    return df
# Define parameters
windows = [2, 3, 4, 5, 7, 14, 21, 30]

# Apply the function to your DataFrame
df_train = create_rolling_features(df_train, lag_cols, windows)
df_valid = create_rolling_features(df_valid, lag_cols, windows)
df_test = create_rolling_features(df_test, lag_cols, windows)
# Out:
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_mean_{window}'] = shifted.rolling(window=window, min_periods=min_periods).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_std_{window}'] = shifted.rolling(window=window, min_periods=min_periods).std()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_min_{window}'] = shifted.rolling(window=window, min_periods=min_periods).min()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_max_{window}'] = shifted.rolling(window=window, min_periods=min_periods).max()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_mean_{window}'] = shifted.rolling(window=window, min_periods=min_periods).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_std_{window}'] = shifted.rolling(window=window, min_periods=min_periods).std()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_min_{window}'] = shifted.rolling(window=window, min_periods=min_periods).min()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_max_{window}'] = shifted.rolling(window=window, min_periods=min_periods).max()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_mean_{window}'] = shifted.rolling(window=window, min_periods=min_periods).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_std_{window}'] = shifted.rolling(window=window, min_periods=min_periods).std()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_min_{window}'] = shifted.rolling(window=window, min_periods=min_periods).min()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_max_{window}'] = shifted.rolling(window=window, min_periods=min_periods).max()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_mean_{window}'] = shifted.rolling(window=window, min_periods=min_periods).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_std_{window}'] = shifted.rolling(window=window, min_periods=min_periods).std()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_min_{window}'] = shifted.rolling(window=window, min_periods=min_periods).min()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_max_{window}'] = shifted.rolling(window=window, min_periods=min_periods).max()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_mean_{window}'] = shifted.rolling(window=window, min_periods=min_periods).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_std_{window}'] = shifted.rolling(window=window, min_periods=min_periods).std()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_min_{window}'] = shifted.rolling(window=window, min_periods=min_periods).min()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_max_{window}'] = shifted.rolling(window=window, min_periods=min_periods).max()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_mean_{window}'] = shifted.rolling(window=window, min_periods=min_periods).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_std_{window}'] = shifted.rolling(window=window, min_periods=min_periods).std()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_min_{window}'] = shifted.rolling(window=window, min_periods=min_periods).min()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_max_{window}'] = shifted.rolling(window=window, min_periods=min_periods).max()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_mean_{window}'] = shifted.rolling(window=window, min_periods=min_periods).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_std_{window}'] = shifted.rolling(window=window, min_periods=min_periods).std()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_min_{window}'] = shifted.rolling(window=window, min_periods=min_periods).min()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_max_{window}'] = shifted.rolling(window=window, min_periods=min_periods).max()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_mean_{window}'] = shifted.rolling(window=window, min_periods=min_periods).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_std_{window}'] = shifted.rolling(window=window, min_periods=min_periods).std()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_min_{window}'] = shifted.rolling(window=window, min_periods=min_periods).min()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_max_{window}'] = shifted.rolling(window=window, min_periods=min_periods).max()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_mean_{window}'] = shifted.rolling(window=window, min_periods=min_periods).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_std_{window}'] = shifted.rolling(window=window, min_periods=min_periods).std()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_mean_{window}'] = shifted.rolling(window=window, min_periods=min_periods).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_std_{window}'] = shifted.rolling(window=window, min_periods=min_periods).std()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_mean_{window}'] = shifted.rolling(window=window, min_periods=min_periods).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_std_{window}'] = shifted.rolling(window=window, min_periods=min_periods).std()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_mean_{window}'] = shifted.rolling(window=window, min_periods=min_periods).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_std_{window}'] = shifted.rolling(window=window, min_periods=min_periods).std()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_mean_{window}'] = shifted.rolling(window=window, min_periods=min_periods).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_std_{window}'] = shifted.rolling(window=window, min_periods=min_periods).std()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_mean_{window}'] = shifted.rolling(window=window, min_periods=min_periods).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_std_{window}'] = shifted.rolling(window=window, min_periods=min_periods).std()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_mean_{window}'] = shifted.rolling(window=window, min_periods=min_periods).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_std_{window}'] = shifted.rolling(window=window, min_periods=min_periods).std()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_roll_mean_{window}'] = shifted.rolling(window=window, min_periods=min_periods).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_mean_{window}'] = shifted.rolling(window=window, min_periods=min_periods).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_roll_std_{window}'] = shifted.rolling(window=window, min_periods=min_periods).std()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_std_{window}'] = shifted.rolling(window=window, min_periods=min_periods).std()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_roll_mean_{window}'] = shifted.rolling(window=window, min_periods=min_periods).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_mean_{window}'] = shifted.rolling(window=window, min_periods=min_periods).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_roll_std_{window}'] = shifted.rolling(window=window, min_periods=min_periods).std()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_std_{window}'] = shifted.rolling(window=window, min_periods=min_periods).std()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_roll_min_{window}'] = shifted.rolling(window=window, min_periods=min_periods).min()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_min_{window}'] = shifted.rolling(window=window, min_periods=min_periods).min()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_roll_max_{window}'] = shifted.rolling(window=window, min_periods=min_periods).max()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_max_{window}'] = shifted.rolling(window=window, min_periods=min_periods).max()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_roll_mean_{window}'] = shifted.rolling(window=window, min_periods=min_periods).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_mean_{window}'] = shifted.rolling(window=window, min_periods=min_periods).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_roll_std_{window}'] = shifted.rolling(window=window, min_periods=min_periods).std()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_std_{window}'] = shifted.rolling(window=window, min_periods=min_periods).std()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_roll_min_{window}'] = shifted.rolling(window=window, min_periods=min_periods).min()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_min_{window}'] = shifted.rolling(window=window, min_periods=min_periods).min()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_roll_max_{window}'] = shifted.rolling(window=window, min_periods=min_periods).max()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_max_{window}'] = shifted.rolling(window=window, min_periods=min_periods).max()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_roll_mean_{window}'] = shifted.rolling(window=window, min_periods=min_periods).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_mean_{window}'] = shifted.rolling(window=window, min_periods=min_periods).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_roll_std_{window}'] = shifted.rolling(window=window, min_periods=min_periods).std()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_std_{window}'] = shifted.rolling(window=window, min_periods=min_periods).std()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_roll_min_{window}'] = shifted.rolling(window=window, min_periods=min_periods).min()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_min_{window}'] = shifted.rolling(window=window, min_periods=min_periods).min()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_roll_max_{window}'] = shifted.rolling(window=window, min_periods=min_periods).max()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_max_{window}'] = shifted.rolling(window=window, min_periods=min_periods).max()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_roll_mean_{window}'] = shifted.rolling(window=window, min_periods=min_periods).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_mean_{window}'] = shifted.rolling(window=window, min_periods=min_periods).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_roll_std_{window}'] = shifted.rolling(window=window, min_periods=min_periods).std()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_std_{window}'] = shifted.rolling(window=window, min_periods=min_periods).std()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_roll_min_{window}'] = shifted.rolling(window=window, min_periods=min_periods).min()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_min_{window}'] = shifted.rolling(window=window, min_periods=min_periods).min()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_roll_max_{window}'] = shifted.rolling(window=window, min_periods=min_periods).max()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_max_{window}'] = shifted.rolling(window=window, min_periods=min_periods).max()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_roll_mean_{window}'] = shifted.rolling(window=window, min_periods=min_periods).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_mean_{window}'] = shifted.rolling(window=window, min_periods=min_periods).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_roll_std_{window}'] = shifted.rolling(window=window, min_periods=min_periods).std()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_std_{window}'] = shifted.rolling(window=window, min_periods=min_periods).std()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_roll_min_{window}'] = shifted.rolling(window=window, min_periods=min_periods).min()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_min_{window}'] = shifted.rolling(window=window, min_periods=min_periods).min()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_roll_max_{window}'] = shifted.rolling(window=window, min_periods=min_periods).max()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_max_{window}'] = shifted.rolling(window=window, min_periods=min_periods).max()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_roll_mean_{window}'] = shifted.rolling(window=window, min_periods=min_periods).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_mean_{window}'] = shifted.rolling(window=window, min_periods=min_periods).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_roll_std_{window}'] = shifted.rolling(window=window, min_periods=min_periods).std()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_std_{window}'] = shifted.rolling(window=window, min_periods=min_periods).std()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_roll_min_{window}'] = shifted.rolling(window=window, min_periods=min_periods).min()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_min_{window}'] = shifted.rolling(window=window, min_periods=min_periods).min()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_roll_max_{window}'] = shifted.rolling(window=window, min_periods=min_periods).max()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_max_{window}'] = shifted.rolling(window=window, min_periods=min_periods).max()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_roll_mean_{window}'] = shifted.rolling(window=window, min_periods=min_periods).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_mean_{window}'] = shifted.rolling(window=window, min_periods=min_periods).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_roll_std_{window}'] = shifted.rolling(window=window, min_periods=min_periods).std()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_std_{window}'] = shifted.rolling(window=window, min_periods=min_periods).std()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_roll_min_{window}'] = shifted.rolling(window=window, min_periods=min_periods).min()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_min_{window}'] = shifted.rolling(window=window, min_periods=min_periods).min()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_roll_max_{window}'] = shifted.rolling(window=window, min_periods=min_periods).max()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_max_{window}'] = shifted.rolling(window=window, min_periods=min_periods).max()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_roll_mean_{window}'] = shifted.rolling(window=window, min_periods=min_periods).mean()
# ...
#   df[f'{col}_roll_min_{window}'] = shifted.rolling(window=window, min_periods=min_periods).min()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_min_{window}'] = shifted.rolling(window=window, min_periods=min_periods).min()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_roll_max_{window}'] = shifted.rolling(window=window, min_periods=min_periods).max()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_max_{window}'] = shifted.rolling(window=window, min_periods=min_periods).max()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_roll_sum_{window}'] = shifted.rolling(window=window, min_periods=min_periods).sum()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_sum_{window}'] = shifted.rolling(window=window, min_periods=min_periods).sum()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_roll_mean_{window}'] = shifted.rolling(window=window, min_periods=min_periods).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_mean_{window}'] = shifted.rolling(window=window, min_periods=min_periods).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_roll_std_{window}'] = shifted.rolling(window=window, min_periods=min_periods).std()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_std_{window}'] = shifted.rolling(window=window, min_periods=min_periods).std()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_roll_min_{window}'] = shifted.rolling(window=window, min_periods=min_periods).min()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_min_{window}'] = shifted.rolling(window=window, min_periods=min_periods).min()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_roll_max_{window}'] = shifted.rolling(window=window, min_periods=min_periods).max()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_max_{window}'] = shifted.rolling(window=window, min_periods=min_periods).max()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_roll_sum_{window}'] = shifted.rolling(window=window, min_periods=min_periods).sum()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_sum_{window}'] = shifted.rolling(window=window, min_periods=min_periods).sum()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_roll_mean_{window}'] = shifted.rolling(window=window, min_periods=min_periods).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_mean_{window}'] = shifted.rolling(window=window, min_periods=min_periods).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_roll_std_{window}'] = shifted.rolling(window=window, min_periods=min_periods).std()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_std_{window}'] = shifted.rolling(window=window, min_periods=min_periods).std()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_roll_min_{window}'] = shifted.rolling(window=window, min_periods=min_periods).min()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_min_{window}'] = shifted.rolling(window=window, min_periods=min_periods).min()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_roll_max_{window}'] = shifted.rolling(window=window, min_periods=min_periods).max()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_max_{window}'] = shifted.rolling(window=window, min_periods=min_periods).max()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_roll_sum_{window}'] = shifted.rolling(window=window, min_periods=min_periods).sum()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_sum_{window}'] = shifted.rolling(window=window, min_periods=min_periods).sum()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_roll_mean_{window}'] = shifted.rolling(window=window, min_periods=min_periods).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_mean_{window}'] = shifted.rolling(window=window, min_periods=min_periods).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_roll_std_{window}'] = shifted.rolling(window=window, min_periods=min_periods).std()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_std_{window}'] = shifted.rolling(window=window, min_periods=min_periods).std()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_roll_min_{window}'] = shifted.rolling(window=window, min_periods=min_periods).min()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_min_{window}'] = shifted.rolling(window=window, min_periods=min_periods).min()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_roll_max_{window}'] = shifted.rolling(window=window, min_periods=min_periods).max()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_max_{window}'] = shifted.rolling(window=window, min_periods=min_periods).max()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_roll_sum_{window}'] = shifted.rolling(window=window, min_periods=min_periods).sum()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\4074857366.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_roll_sum_{window}'] = shifted.rolling(window=window, min_periods=min_periods).sum()

# %% [markdown]
# ### Weighted Rolling Feature

# %%
def create_ewma_features(df, lag_cols, spans):
    """
    Create Exponentially Weighted Moving Average (EWMA) features for specified columns.

    Parameters:
    - df (pd.DataFrame): The input DataFrame.
    - lag_cols (list): List of column names to create EWMA features for.
    - spans (list): List of span values for EWMA calculations.

    Returns:
    - pd.DataFrame: DataFrame with EWMA features added.
    """
    for col in lag_cols:
        for span in spans:
            df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
    return df

# Define parameters
spans = [2, 3, 4, 5, 7, 14, 21, 30]

# Apply the function to your DataFrame
df_train = create_ewma_features(df_train, lag_cols, spans)
df_train = df_train.dropna()
df_valid = create_ewma_features(df_valid, lag_cols, spans)
df_valid = df_valid.dropna()
df_test = create_ewma_features(df_test, lag_cols, spans)
df_test = df_test.dropna()
# Out:
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# ...
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\49816739.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_ewm_{span}'] = df[col].ewm(span=span, adjust=False).mean()

# %% [markdown]
# ### Feature Interaction

# %%
def create_interaction_features(df):
    """
    Create interaction features for the given DataFrame.

    Parameters:
    - df (pd.DataFrame): The input DataFrame.

    Returns:
    - pd.DataFrame: DataFrame with new interaction features added.
    """
    # Hiệu ứng của nhiệt độ 1 ngày trước trong mùa hè
    df['interaction_lag1_summer'] = df['temp_lag_1'] * df['season_Summer']

    # Hiệu ứng của nhiệt độ 1 ngày trước vào cuối tuần
    df['interaction_lag1_weekend'] = df['temp_lag_1'] * df['is_weekend']

    # "Hiệu ứng gió lạnh" = tốc độ gió * (mức độ quang đãng của bầu trời)
    df['interaction_wind_clearsky_effect'] = df['windspeed'] * (1 - df['cloudcover'] / 100.0)

    # Bức xạ hiệu dụng (Effective Solar Radiation)
    df['effective_radiation'] = df['uvindex'] * (1 - df['cloudcover'] / 100)

    # Tương tác giữa Độ ẩm và Nhiệt độ
    df['humidity_temp_interact'] = df['humidity'] * df['temp']

    return df
# Áp dụng hàm để tạo các feature tương tác
df_train = create_interaction_features(df_train)
df_valid = create_interaction_features(df_valid)
df_test = create_interaction_features(df_test)
# Out:
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3449079675.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['interaction_lag1_summer'] = df['temp_lag_1'] * df['season_Summer']
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3449079675.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['interaction_lag1_weekend'] = df['temp_lag_1'] * df['is_weekend']
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3449079675.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['interaction_wind_clearsky_effect'] = df['windspeed'] * (1 - df['cloudcover'] / 100.0)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3449079675.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['effective_radiation'] = df['uvindex'] * (1 - df['cloudcover'] / 100)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3449079675.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['humidity_temp_interact'] = df['humidity'] * df['temp']
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3449079675.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['interaction_lag1_summer'] = df['temp_lag_1'] * df['season_Summer']
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3449079675.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['interaction_lag1_weekend'] = df['temp_lag_1'] * df['is_weekend']
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3449079675.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['interaction_wind_clearsky_effect'] = df['windspeed'] * (1 - df['cloudcover'] / 100.0)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3449079675.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['effective_radiation'] = df['uvindex'] * (1 - df['cloudcover'] / 100)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3449079675.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['humidity_temp_interact'] = df['humidity'] * df['temp']
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3449079675.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['interaction_lag1_summer'] = df['temp_lag_1'] * df['season_Summer']
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3449079675.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['interaction_lag1_weekend'] = df['temp_lag_1'] * df['is_weekend']
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3449079675.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['interaction_wind_clearsky_effect'] = df['windspeed'] * (1 - df['cloudcover'] / 100.0)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3449079675.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['effective_radiation'] = df['uvindex'] * (1 - df['cloudcover'] / 100)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3449079675.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['humidity_temp_interact'] = df['humidity'] * df['temp']

# %% [markdown]
# ### Hourly Rolling Feature
# - The rolling feature created by the mean of temperature in a range of hour.

# %%
rolling_hour_feature = ['temp', 'feelslike', 'dew', 'humidity', 'precip', 'precipprob', 'windspeed', 'uvindex']
window_sizes = [3, 6, 9, 12, 15, 18]  # Các giá trị window

def create_rolling_hour_feature(df_infunc:pd.DataFrame):
    # Tạo dataframe tạm thời để lưu các feature rolling
    df_temp = pd.DataFrame(index=df.index)
    
    # Tính rolling feature cho từng feature và từng window size
    for feature in rolling_hour_feature:
        for window in window_sizes:
            col_name = f'{feature}_rolling_last_{window}h'
            df_temp[col_name] = df[feature].rolling(window=window).mean()
    
    # Tái cấu trúc thời gian dữ liệu rolling về daily và lưu vào df_daily
    for col in df_temp.columns:
        df_infunc[col] = df_temp[col].resample('D').last()
    
    # Xóa dataframe tạm thời để bảo toàn tài nguyên
    del df_temp

# Gọi hàm để tạo rolling features cho train, test, split
create_rolling_hour_feature(df_train)
create_rolling_hour_feature(df_valid)
create_rolling_hour_feature(df_test)
# Out:
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\3810028225.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_infunc[col] = df_temp[col].resample('D').last()

# %% [markdown]
# ## X/y Splitting
# - Creating Label

# %%
def create_target_features(df, horizons):
    """
    Create target features for forecasting based on specified horizons.

    Parameters:
    - df (pd.DataFrame): The input DataFrame containing the 'temp' column.
    - horizons (list): List of horizons (time steps) for which to create target features.

    Returns:
    - pd.DataFrame: DataFrame with target features added and NaN rows dropped.
    """
    for h in horizons:
        df[f'target_temp_t+{h}'] = df['temp'].shift(-h)
    return df.dropna()

# Example usage:
horizons = [1, 2, 3, 4, 5]
df_train = create_target_features(df_train, horizons)
df_train = df_train.dropna()
df_valid = create_target_features(df_valid, horizons)
df_valid = df_valid.dropna()
df_test = create_target_features(df_test, horizons)
df_test = df_test.dropna()
# Out:
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\2711689558.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'target_temp_t+{h}'] = df['temp'].shift(-h)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\2711689558.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'target_temp_t+{h}'] = df['temp'].shift(-h)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\2711689558.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'target_temp_t+{h}'] = df['temp'].shift(-h)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\2711689558.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'target_temp_t+{h}'] = df['temp'].shift(-h)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\2711689558.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'target_temp_t+{h}'] = df['temp'].shift(-h)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\2711689558.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'target_temp_t+{h}'] = df['temp'].shift(-h)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\2711689558.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'target_temp_t+{h}'] = df['temp'].shift(-h)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\2711689558.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'target_temp_t+{h}'] = df['temp'].shift(-h)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\2711689558.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'target_temp_t+{h}'] = df['temp'].shift(-h)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\2711689558.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'target_temp_t+{h}'] = df['temp'].shift(-h)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\2711689558.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'target_temp_t+{h}'] = df['temp'].shift(-h)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\2711689558.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'target_temp_t+{h}'] = df['temp'].shift(-h)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\2711689558.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'target_temp_t+{h}'] = df['temp'].shift(-h)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\2711689558.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'target_temp_t+{h}'] = df['temp'].shift(-h)
# C:\Users\Huy\AppData\Local\Temp\ipykernel_23780\2711689558.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'target_temp_t+{h}'] = df['temp'].shift(-h)

# %% [markdown]
# - Feature\Label Splitting

# %%
def feature_label_split(df_infunc: pd.DataFrame, horizons=[1, 2, 3, 4, 5]):
    X = df_infunc.drop([f'target_temp_t+{h}' for h in horizons], axis=1)
    y = df_infunc[[f'target_temp_t+{h}' for h in horizons]]
    return X, y

X_train, y_train = feature_label_split(df_train)
X_valid, y_valid = feature_label_split(df_valid)
X_test, y_test = feature_label_split(df_test)
print(X_train.shape, y_train.shape)
# Out:
# (2522, 316) (2522, 5)

# %%
# Check for non-numeric features in the DataFrame
non_numeric_features = df_train.select_dtypes(exclude=[np.number]).columns.tolist()

if non_numeric_features:
    print("Non-numeric features found:")
    print(non_numeric_features)
else:
    print("All features are numeric.")
# Out:
# All features are numeric.

# %% [markdown]
# ## Handle Multicollinearity

# %%
# Select numeric columns
num_df = X_train.select_dtypes(include=[np.number])

# Compute Pearson correlation
corr_matrix = num_df.corr()

top_corr = corr_matrix['temp'].abs().sort_values(ascending=False).head(40)

# Handling multicolinearity

def find_highly_correlated_features(corr_matrix, threshold=0.95):
    """
    Find feature pairs with correlation above the specified threshold.
    """
    # Get the upper triangle of the correlation matrix
    upper_tri = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))

    # Find feature pairs with correlation > threshold
    highly_correlated_pairs = [
        (column, upper_tri[column].abs().idxmax(), upper_tri[column].abs().max())
        for column in upper_tri.columns if upper_tri[column].abs().max() > threshold
    ]

    # Sort for easier viewing
    sorted_pairs = sorted(highly_correlated_pairs, key=lambda x: x[2], reverse=True)

    return sorted_pairs


def drop_correlated_features(df, correlated_pairs, target_col):
    """
    Drop one feature from each highly correlated pair.
    This function keeps the feature that has higher correlation with the target variable.
    Args:
        df (pd.DataFrame): The DataFrame containing the data.
        correlated_pairs (list): List of highly correlated feature pairs from the find_highly_correlated_features function.
        target_col (str): The name of the target column (e.g., 'temp').
    Returns:
        pd.DataFrame: The new DataFrame with features dropped.
        set: A set of dropped columns.
    """
    cols_to_drop = set()

    # Calculate correlation of all features with the target column once
    corr_with_target = df.corr()[target_col].abs()

    # Iterate through the pairs found
    for feat1, feat2, _ in correlated_pairs:
        # Get the correlation values with the target for each feature in the pair
        corr1 = corr_with_target.get(feat1, 0)
        corr2 = corr_with_target.get(feat2, 0)

        # Decide which feature to drop
        if corr1 > corr2:
            # Keep feat1, drop feat2
            cols_to_drop.add(feat2)
        else:
            # Keep feat2, drop feat1
            cols_to_drop.add(feat1)

    # Drop the identified columns
    df_reduced = df.drop(columns=list(cols_to_drop))

    print(f"\nDropped {len(cols_to_drop)} features due to multicollinearity.")
    if cols_to_drop:
        print("- Dropped columns:", list(cols_to_drop))

    return df_reduced, cols_to_drop

correlated_pairs = find_highly_correlated_features(corr_matrix, threshold=0.70)

print("\n feature pairs with very high correlation (> 0.70):")
for feat1, feat2, corr_val in correlated_pairs:
    print(f"- {feat1:<25} and {feat2:<25} : {corr_val:.4f}")

X_train, dropped_cols = drop_correlated_features(df=X_train,
                                                  correlated_pairs=correlated_pairs,
                                                  target_col='temp')
X_valid = X_valid[X_train.columns]
X_test = X_test[X_train.columns]
# Out:
#  feature pairs with very high correlation (> 0.70):
# - precip_roll_sum_3         and precip_roll_mean_3        : 1.0000
# - precip_roll_sum_30        and precip_roll_mean_30       : 1.0000
# - precip_roll_sum_21        and precip_roll_mean_21       : 1.0000
# - precip_roll_sum_2         and precip_roll_mean_2        : 1.0000
# - precip_roll_sum_4         and precip_roll_mean_4        : 1.0000
# - precip_roll_sum_7         and precip_roll_mean_7        : 1.0000
# - precip_roll_sum_5         and precip_roll_mean_5        : 1.0000
# - precip_roll_sum_14        and precip_roll_mean_14       : 1.0000
# - precip_rolling_last_15h   and precip_rolling_last_12h   : 0.9997
# - uvindex_rolling_last_18h  and uvindex                   : 0.9993
# - dew_rolling_last_18h      and dew_rolling_last_15h      : 0.9990
# - temp_ewm_5                and temp_ewm_4                : 0.9990
# - dew_rolling_last_15h      and dew_rolling_last_12h      : 0.9990
# - temp_rolling_last_15h     and temp_rolling_last_12h     : 0.9988
# - dew_rolling_last_12h      and dew_rolling_last_9h       : 0.9987
# - temp_rolling_last_18h     and temp_rolling_last_15h     : 0.9986
# - feelslike_rolling_last_18h and feelslike_rolling_last_15h : 0.9986
# - temp_ewm_4                and temp_ewm_3                : 0.9984
# - uvindex_rolling_last_15h  and uvindex                   : 0.9984
# - feelslike_rolling_last_15h and feelslike_rolling_last_12h : 0.9983
# - temp_rolling_last_12h     and temp_rolling_last_9h      : 0.9982
# - precip_roll_max_5         and precip_roll_std_5         : 0.9981
# - temp_ewm_7                and temp_ewm_5                : 0.9978
# - temp_ewm_2                and temp_roll_mean_2          : 0.9977
# - feelslike_rolling_last_12h and feelslike_rolling_last_9h : 0.9975
# - precip_roll_max_4         and precip_roll_std_4         : 0.9974
# - precip_roll_max_7         and precip_roll_std_7         : 0.9974
# - interaction_lag1_summer   and season_Summer             : 0.9971
# - temp_ewm_3                and temp_ewm_2                : 0.9971
# - dew_rolling_last_9h       and dew_rolling_last_6h       : 0.9969
# - month                     and day_of_year               : 0.9965
# - temp_ewm_21               and temp_ewm_14               : 0.9963
# - temp_ewm_30               and temp_ewm_21               : 0.9961
# - humidity_ewm_5            and humidity_ewm_4            : 0.9960
# - temp_rolling_last_6h      and temp_rolling_last_3h      : 0.9958
# - temp_rolling_last_9h      and temp_rolling_last_6h      : 0.9957
# - temp_roll_mean_5          and temp_roll_mean_4          : 0.9956
# - cloudcover_ewm_5          and cloudcover_ewm_4          : 0.9956
# - dew_rolling_last_6h       and dew_rolling_last_3h       : 0.9954
# - windspeed_ewm_5           and windspeed_ewm_4           : 0.9949
# - feelslike_rolling_last_9h and feelslike_rolling_last_6h : 0.9947
# - humidity_rolling_last_15h and humidity_rolling_last_12h : 0.9942
# - precip_ewm_5              and precip_ewm_4              : 0.9942
# - temp_roll_mean_4          and temp_roll_mean_3          : 0.9940
# - humidity_rolling_last_18h and humidity_rolling_last_15h : 0.9939
# - temp_roll_min_2           and temp_roll_mean_2          : 0.9938
# - humidity_ewm_4            and humidity_ewm_3            : 0.9937
# - temp_roll_max_2           and temp_roll_mean_2          : 0.9934
# - feelslike_rolling_last_6h and feelslike_rolling_last_3h : 0.9932
# - cloudcover_ewm_4          and cloudcover_ewm_3          : 0.9930
# - temp_ewm_14               and temp_roll_mean_14         : 0.9928
# - precip_roll_max_14        and precip_roll_std_14        : 0.9928
# - precip_roll_max_3         and precip_roll_std_3         : 0.9922
# - windspeed_ewm_4           and windspeed_ewm_3           : 0.9917
# - temp_roll_min_5           and temp_roll_min_4           : 0.9917
# - humidity_rolling_last_12h and humidity_rolling_last_9h  : 0.9914
# - temp_roll_mean_3          and temp_roll_mean_2          : 0.9913
# - humidity_ewm_7            and humidity_ewm_5            : 0.9905
# - temp_roll_min_4           and temp_roll_min_3           : 0.9904
# - precip_ewm_4              and precip_ewm_3              : 0.9903
# - temp_roll_mean_7          and temp_roll_mean_5          : 0.9899
# - temp_roll_mean_30         and temp_roll_mean_21         : 0.9899
# - cloudcover_ewm_7          and cloudcover_ewm_5          : 0.9896
# - temp_roll_min_3           and temp_roll_min_2           : 0.9889
# - humidity_ewm_3            and humidity_ewm_2            : 0.9887
# - humidity_ewm_30           and humidity_ewm_21           : 0.9884
# - windspeed_ewm_7           and windspeed_ewm_5           : 0.9883
# - windspeed_ewm_30          and windspeed_ewm_21          : 0.9879
# - temp_roll_mean_21         and temp_roll_mean_14         : 0.9878
# - precip_roll_max_21        and precip_roll_std_21        : 0.9876
# - humidity_temp_interact    and dew                       : 0.9875
# - cloudcover_ewm_30         and cloudcover_ewm_21         : 0.9874
# - precip_ewm_30             and precip_ewm_21             : 0.9873
# - cloudcover_ewm_3          and cloudcover_ewm_2          : 0.9871
# - humidity_ewm_2            and humidity_roll_mean_2      : 0.9869
# - precip_ewm_7              and precip_ewm_5              : 0.9869
# - temp_roll_mean_2          and temp                      : 0.9862
# - temp_roll_max_3           and temp_roll_mean_3          : 0.9859
# - humidity_ewm_21           and humidity_ewm_14           : 0.9854
# - windspeed_rolling_last_18h and windspeed_rolling_last_15h : 0.9850
# - windspeed_ewm_3           and windspeed_ewm_2           : 0.9844
# - cloudcover_ewm_21         and cloudcover_ewm_14         : 0.9842
# - windspeed_ewm_21          and windspeed_ewm_14          : 0.9838
# - temp_roll_max_5           and temp_roll_max_4           : 0.9832
# - precip_ewm_21             and precip_ewm_14             : 0.9827
# - temp_roll_min_7           and temp_roll_min_5           : 0.9825
# - precip_rolling_last_9h    and precip_rolling_last_6h    : 0.9823
# - cloudcover_ewm_2          and cloudcover_roll_mean_2    : 0.9821
# - precip_roll_max_2         and precip_roll_mean_2        : 0.9809
# - precip_ewm_3              and precip_ewm_2              : 0.9808
# - precip_roll_max_30        and precip_roll_std_30        : 0.9801
# - temp_roll_max_4           and temp_roll_max_3           : 0.9801
# - temp_rolling_last_3h      and temp                      : 0.9789
# - humidity_roll_mean_5      and humidity_roll_mean_4      : 0.9789
# - uvindex_rolling_last_12h  and uvindex                   : 0.9787
# - temp_roll_min_30          and temp_roll_min_21          : 0.9773
# - temp_roll_min_21          and temp_roll_min_14          : 0.9772
# - humidity_rolling_last_9h  and humidity_rolling_last_6h  : 0.9770
# - feelslike                 and temp                      : 0.9758
# - temp_roll_max_30          and temp_roll_max_21          : 0.9751
# - windspeed_rolling_last_15h and windspeed_rolling_last_12h : 0.9751
# - cloudcover_roll_mean_5    and cloudcover_roll_mean_4    : 0.9742
# - temp_roll_min_14          and temp_roll_mean_14         : 0.9728
# - humidity_roll_mean_4      and humidity_roll_mean_3      : 0.9719
# - temp_roll_mean_14         and temp_roll_mean_7          : 0.9715
# - interaction_lag1_weekend  and is_weekend                : 0.9711
# - temp_roll_max_7           and temp_roll_mean_7          : 0.9709
# - windspeed_ewm_2           and windspeed_roll_mean_2     : 0.9708
# - dew_rolling_last_3h       and dew                       : 0.9706
# - windspeed_rolling_last_12h and windspeed_rolling_last_9h : 0.9702
# - temp_roll_max_21          and temp_roll_max_14          : 0.9701
# - temp_roll_max_14          and temp_roll_mean_14         : 0.9665
# - cloudcover_roll_mean_4    and cloudcover_roll_mean_3    : 0.9653
# - windspeed_roll_mean_5     and windspeed_roll_mean_4     : 0.9633
# - feelslike_rolling_last_3h and temp_rolling_last_3h      : 0.9628
# - humidity_rolling_last_6h  and humidity_rolling_last_3h  : 0.9612
# - windspeed_rolling_last_9h and windspeed_rolling_last_6h : 0.9606
# - precipprob_rolling_last_18h and precipprob_rolling_last_15h : 0.9605
# - humidity_roll_mean_3      and humidity_roll_mean_2      : 0.9599
# - humidity_ewm_14           and humidity_ewm_7            : 0.9593
# - precipprob_rolling_last_15h and precipprob_rolling_last_12h : 0.9592
# - cloudcover_ewm_14         and cloudcover_ewm_7          : 0.9557
# - windspeed_roll_max_2      and windspeed_roll_mean_2     : 0.9542
# - windspeed_ewm_14          and windspeed_ewm_7           : 0.9521
# - humidity_roll_mean_7      and humidity_roll_mean_5      : 0.9512
# - windspeed_roll_mean_4     and windspeed_roll_mean_3     : 0.9512
# - cloudcover_roll_mean_3    and cloudcover_roll_mean_2    : 0.9500
# - precip_ewm_14             and precip_ewm_7              : 0.9480
# - precip_roll_std_5         and precip_roll_mean_5        : 0.9477
# - precip_roll_std_4         and precip_roll_mean_4        : 0.9456
# - precip_ewm_2              and precip                    : 0.9456
# - temp_lag_2                and temp_lag_1                : 0.9453
# - temp_lag_3                and temp_lag_2                : 0.9453
# - temp_lag_1                and temp                      : 0.9453
# - temp_lag_5                and temp_lag_4                : 0.9453
# - temp_lag_4                and temp_lag_3                : 0.9453
# - cloudcover_roll_mean_7    and cloudcover_roll_mean_5    : 0.9436
# - precip_roll_std_7         and precip_roll_mean_7        : 0.9413
# - windspeed_roll_min_2      and windspeed_roll_mean_2     : 0.9404
# - precip_roll_std_3         and precip_roll_mean_3        : 0.9351
# - humidity_roll_mean_30     and humidity_roll_mean_21     : 0.9344
# - humidity_roll_mean_2      and humidity_lag_1            : 0.9341
# - windspeed_rolling_last_6h and windspeed_rolling_last_3h : 0.9335
# - precip_roll_mean_5        and precip_roll_mean_4        : 0.9318
# - windspeed_roll_mean_3     and windspeed_roll_mean_2     : 0.9292
# - windspeed_roll_min_5      and windspeed_roll_min_4      : 0.9259
# - cloudcover_roll_mean_30   and cloudcover_roll_mean_21   : 0.9235
# - windspeed_roll_mean_7     and windspeed_roll_mean_5     : 0.9232
# - precip_rolling_last_18h   and precip                    : 0.9221
# - precip_roll_std_14        and precip_roll_mean_14       : 0.9210
# - windspeed_roll_mean_30    and windspeed_roll_mean_21    : 0.9187
# - humidity_roll_mean_21     and humidity_roll_mean_14     : 0.9186
# - precipprob_rolling_last_9h and precipprob_rolling_last_6h : 0.9186
# - cloudcover_roll_mean_2    and cloudcover_lag_1          : 0.9163
# - windspeed_roll_max_5      and windspeed_roll_max_4      : 0.9128
# - precip_roll_mean_4        and precip_roll_mean_3        : 0.9094
# - precip_roll_mean_30       and precip_roll_mean_21       : 0.9080
# - cloudcover_roll_std_30    and cloudcover_roll_std_21    : 0.9075
# - cloudcover_roll_mean_21   and cloudcover_roll_mean_14   : 0.9066
# - precip_roll_std_21        and precip_roll_mean_21       : 0.9066
# - windspeed_roll_max_3      and windspeed_roll_mean_3     : 0.9057
# - effective_radiation       and cloudcover                : 0.9047
# - windspeed_roll_min_4      and windspeed_roll_min_3      : 0.9042
# - uvindex_rolling_last_9h   and uvindex                   : 0.9011
# - dew                       and temp                      : 0.8997
# - windspeed_roll_max_4      and windspeed_roll_max_3      : 0.8994
# - precip_roll_std_2         and precip_roll_mean_2        : 0.8968
# - windspeed_roll_mean_21    and windspeed_roll_mean_14    : 0.8948
# - precip_roll_std_30        and precip_roll_mean_30       : 0.8944
# - windspeed_roll_min_3      and windspeed_roll_mean_3     : 0.8935
# - cloudcover_roll_std_5     and cloudcover_roll_std_4     : 0.8927
# - humidity_roll_std_5       and humidity_roll_std_4       : 0.8925
# - precipprob_rolling_last_12h and precipprob_rolling_last_9h : 0.8913
# - precip_roll_mean_7        and precip_roll_mean_5        : 0.8899
# - temp_seasonal_yearly      and day_cos                   : 0.8898
# - precip_roll_mean_21       and precip_roll_sum_14        : 0.8855
# - windspeed_roll_std_30     and windspeed_roll_std_21     : 0.8842
# - temp_roll_std_5           and temp_roll_std_4           : 0.8830
# - sealevelpressure          and feelslike                 : 0.8816
# - windspeed_roll_mean_2     and windspeed                 : 0.8795
# - temp_lag_7                and temp_lag_5                : 0.8759
# - windspeed_roll_min_7      and windspeed_roll_min_5      : 0.8757
# - precip_roll_mean_3        and precip_roll_mean_2        : 0.8716
# - windspeed_roll_std_5      and windspeed_roll_std_4      : 0.8707
# - temp_roll_std_30          and temp_roll_std_21          : 0.8707
# - windspeed_roll_min_30     and windspeed_roll_min_21     : 0.8699
# - humidity_roll_std_30      and humidity_roll_std_21      : 0.8692
# - cloudcover_roll_std_21    and cloudcover_roll_std_14    : 0.8684
# - humidity_rolling_last_3h  and humidity                  : 0.8654
# - windspeed_roll_min_21     and windspeed_roll_min_14     : 0.8568
# - day_cos                   and feelslike                 : 0.8518
# - interaction_wind_clearsky_effect and cloudcover                : 0.8458
# - humidity_roll_mean_14     and humidity_roll_mean_7      : 0.8419
# - humidity_roll_std_21      and humidity_roll_std_14      : 0.8410
# - windspeed_roll_max_7      and windspeed_roll_max_5      : 0.8400
# - windspeed_roll_std_21     and windspeed_roll_std_14     : 0.8386
# - cloudcover_roll_std_7     and cloudcover_roll_std_5     : 0.8368
# - cloudcover_roll_std_4     and cloudcover_roll_std_3     : 0.8299
# - humidity_roll_std_4       and humidity_roll_std_3       : 0.8296
# - temp_roll_std_4           and temp_roll_std_3           : 0.8285
# - temp_roll_std_21          and temp_roll_std_14          : 0.8268
# - cloudcover_roll_mean_14   and cloudcover_roll_mean_7    : 0.8262
# - humidity_roll_std_7       and humidity_roll_std_5       : 0.8232
# - temp_lag_14               and temp_seasonal_yearly      : 0.8192
# - windspeed_roll_max_30     and windspeed_roll_max_21     : 0.8164
# - windspeed_roll_std_4      and windspeed_roll_std_3      : 0.8122
# - windspeed_roll_std_7      and windspeed_roll_std_5      : 0.8095
# - windspeed_roll_max_14     and windspeed_roll_std_14     : 0.8010
# - temp_roll_std_7           and temp_roll_std_5           : 0.7978
# - windspeed_roll_mean_14    and windspeed_roll_mean_7     : 0.7975
# - precip_rolling_last_12h   and precip_rolling_last_9h    : 0.7908
# - is_weekend                and day_of_week               : 0.7906
# - windspeed_roll_max_21     and windspeed_roll_std_21     : 0.7820
# - precipprob_rolling_last_6h and precipprob_rolling_last_3h : 0.7815
# - precip_roll_mean_2        and precip_lag_1              : 0.7801
# - precip_roll_mean_14       and precip_roll_mean_7        : 0.7772
# - day_sin                   and day_of_year               : 0.7759
# - icon_clear-night          and conditions_Clear          : 0.7630
# - windspeed                 and windgust                  : 0.7580
# - humidity_lag_5            and humidity_lag_4            : 0.7455
# - humidity_lag_4            and humidity_lag_3            : 0.7454
# - humidity_lag_3            and humidity_lag_2            : 0.7453
# - humidity_lag_2            and humidity_lag_1            : 0.7452
# - humidity_lag_1            and humidity                  : 0.7452
# - temp_lag_30               and temp_lag_14               : 0.7426
# - precip_roll_min_5         and precip_roll_min_4         : 0.7242
# - icon_cloudy               and conditions_Overcast       : 0.7230
# - season_Spring             and day_sin                   : 0.7148
# - season_Summer             and day_cos                   : 0.7130
# - windspeed_roll_min_14     and windspeed_roll_min_7      : 0.7112
# - season_Winter             and day_cos                   : 0.7112
# - cloudcover_roll_std_14    and cloudcover_roll_std_7     : 0.7085
# - humidity_roll_std_3       and humidity_roll_std_2       : 0.7067
# - precip_roll_min_2         and precip_roll_mean_2        : 0.7052
# - temp_roll_std_3           and temp_roll_std_2           : 0.7040
#
# Dropped 202 features due to multicollinearity.
# - Dropped columns: ['season_Summer', 'cloudcover_ewm_3', 'icon_clear-night', 'windspeed_roll_std_14', 'windspeed_roll_max_21', 'cloudcover_roll_std_21', 'temp_roll_mean_14', 'windspeed_roll_max_14', 'temp_lag_7', 'temp_roll_mean_3', 'humidity_roll_std_4', 'windspeed_roll_std_3', 'precip', 'windspeed_ewm_4', 'windspeed_ewm_3', 'humidity_ewm_2', 'temp_roll_max_4', 'temp_roll_mean_7', 'windspeed_roll_min_4', 'temp_rolling_last_9h', 'humidity_ewm_4', 'humidity_roll_std_3', 'windspeed_rolling_last_12h', 'temp_lag_3', 'precipprob_rolling_last_6h', 'temp_roll_std_21', 'cloudcover_roll_std_4', 'windspeed_roll_max_4', 'humidity_roll_mean_21', 'humidity_rolling_last_18h', 'cloudcover_roll_mean_7', 'temp_roll_mean_5', 'precip_roll_max_14', 'precip_ewm_2', 'humidity_roll_std_14', 'feelslike_rolling_last_15h', 'dew_rolling_last_12h', 'precip_roll_std_7', 'humidity_roll_mean_14', 'temp_ewm_7', 'humidity_ewm_3', 'precip_roll_mean_5', 'windspeed_roll_min_14', 'humidity_lag_5', 'uvindex_rolling_last_12h', 'temp_roll_std_3', 'temp_roll_min_5', 'cloudcover_roll_mean_4', 'temp_ewm_3', 'precip_ewm_3', 'temp_roll_mean_30', 'precip_ewm_5', 'cloudcover_roll_mean_30', 'feelslike_rolling_last_6h', 'temp_roll_max_30', 'windspeed_roll_min_21', 'cloudcover_roll_std_14', 'windspeed_ewm_14', 'precip_roll_sum_4', 'precip_roll_max_7', 'windspeed_roll_max_30', 'windspeed_ewm_2', 'humidity', 'cloudcover_ewm_5', 'windspeed_roll_mean_7', 'windspeed_roll_max_5', 'temp_roll_std_14', 'humidity_ewm_5', 'cloudcover_lag_1', 'cloudcover_ewm_2', 'feelslike_rolling_last_9h', 'temp_roll_max_21', 'humidity_roll_mean_7', 'humidity_rolling_last_9h', 'humidity_roll_mean_2', 'windspeed_roll_std_21', 'windspeed_rolling_last_18h', 'precip_roll_mean_2', 'temp_roll_std_4', 'cloudcover_roll_mean_14', 'dew_rolling_last_9h', 'temp_roll_max_14', 'precip_rolling_last_12h', 'temp_ewm_21', 'humidity_temp_interact', 'feelslike_rolling_last_12h', 'windspeed_roll_mean_4', 'precipprob_rolling_last_18h', 'temp_lag_4', 'windspeed_roll_min_3', 'humidity_lag_4', 'temp_roll_min_30', 'humidity_roll_std_21', 'temp_roll_mean_4', 'precip_roll_sum_14', 'windspeed_roll_std_4', 'cloudcover_roll_std_5', 'temp_roll_std_5', 'windspeed_roll_max_3', 'precip_roll_sum_3', 'precip_roll_min_5', 'windspeed_rolling_last_3h', 'uvindex', 'windspeed', 'precip_ewm_4', 'dew', 'humidity_lag_3', 'precip_roll_sum_2', 'humidity_rolling_last_15h', 'humidity_roll_std_5', 'precip_rolling_last_6h', 'dew_rolling_last_3h', 'temp_rolling_last_3h', 'precip_roll_mean_4', 'precip_rolling_last_18h', 'temp_lag_1', 'dew_rolling_last_15h', 'temp_lag_2', 'windspeed_roll_mean_2', 'dew_rolling_last_6h', 'temp_roll_min_3', 'temp_roll_max_3', 'feelslike', 'humidity_roll_mean_4', 'precip_roll_mean_14', 'uvindex_rolling_last_9h', 'temp_rolling_last_6h', 'temp_roll_mean_2', 'cloudcover_ewm_21', 'precip_roll_mean_21', 'temp_ewm_30', 'temp_rolling_last_15h', 'is_weekend', 'precip_lag_1', 'temp_roll_min_21', 'windspeed_roll_min_7', 'precip_ewm_7', 'temp_ewm_4', 'precip_roll_std_3', 'windspeed_roll_mean_14', 'temp_lag_5', 'precip_roll_std_5', 'windspeed_roll_mean_3', 'cloudcover_ewm_30', 'temp_ewm_5', 'humidity_ewm_7', 'temp_roll_std_2', 'temp_rolling_last_12h', 'cloudcover_ewm_4', 'cloudcover_roll_mean_3', 'humidity_roll_mean_5', 'windspeed_roll_mean_21', 'cloudcover_roll_std_3', 'precip_roll_std_14', 'conditions_Overcast', 'season_Spring', 'feelslike_rolling_last_3h', 'precip_roll_min_2', 'temp_roll_mean_21', 'windspeed_roll_std_5', 'precipprob_rolling_last_12h', 'precip_roll_std_4', 'cloudcover_roll_mean_21', 'windspeed_roll_min_5', 'windspeed_ewm_21', 'precip_roll_std_30', 'windspeed_rolling_last_15h', 'humidity_ewm_21', 'humidity_rolling_last_6h', 'precip_roll_std_21', 'precip_roll_sum_7', 'temp_lag_14', 'precipprob_rolling_last_3h', 'uvindex_rolling_last_15h', 'temp_lag_30', 'day_of_year', 'cloudcover_roll_mean_2', 'sealevelpressure', 'season_Winter', 'cloudcover_ewm_14', 'humidity_roll_std_2', 'precip_ewm_14', 'windspeed_rolling_last_9h', 'pr ...

# %% [markdown]
# ## Save dataframe after preprocessing

# %%
import pickle

# Đường dẫn lưu file
output_path = "Hourly Dataframe Preprocessed.pkl"

# Lưu các DataFrame vào file
with open(output_path, 'wb') as f:
    pickle.dump({
        'X_train': X_train,
        'y_train': y_train,
        'X_valid': X_valid,
        'y_valid': y_valid,
        'X_test': X_test,
        'y_test': y_test
    }, f)

print(f"DataFrames have been saved to {output_path}")
